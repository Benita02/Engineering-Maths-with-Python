# %%
import numpy as np 
import matplotlib.pyplot as plt
import sympy

# %%
x = np.linspace(-3, 3, 20)
y = func(x)

fig, ax = plt.subplots()
ax.plot(x, y)

ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Customize axes
ax.set_xlabel("x")
ax.set_ylabel("f(x)")
ax.set_title("Plot of f(x) = x^3 - 3x - 4")
ax.grid(True)
plt.show()

# %%
def func(x):
    return x**2 - 8*x + 6

def func_deriv(x):
    return 2*x - 8

# %%
def newton(func, func_deriv,x0, tol=1e-6, max_iter=100):
    for i in range(max_iter):
        f=func(x0)
        f_prime=func_deriv(x0)
        x1=x0 - f/f_prime
        if abs(x1-x0) < tol:
            print(f"{x1}, is the root found in {i} iterations")
            break
        x0 = x1
        if i == max_iter:
            print("No solution after {} iterations".format(i))

# %%
# testing out the function
solution = newton(func, func_deriv, 1) # From the graph we see that the root is between 0 and 1
# Out:
# 0.8377223398316206, is the root found in 3 iterations
